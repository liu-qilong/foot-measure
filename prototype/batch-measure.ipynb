# %%
import sys
sys.path.append("..")

# %% [markdown]
# ## Load labelling

# %%
import pandas as pd

label_path = '../data/label.pkl'
df = pd.read_pickle(label_path)
df
# Out:
# coord                                                                x  \
# file                                               landmark
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1         3.857714
#                                                    P10       39.322110
#                                                    P11       60.724825
#                                                    P12      -12.828403
#                                                    P2        39.049710
#                                                    P3       -36.862691
#                                                    P4        60.973624
#                                                    P5       -35.013347
#                                                    P6        20.691139
#                                                    P7        21.423839
#                                                    P8        62.182012
#                                                    P9         2.314420
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1       -17.238714
#                                                    P10       27.044899
#                                                    P11       46.314558
#                                                    P12      -12.425996
#                                                    P2        23.827222
#                                                    P3       -48.912331
#                                                    P4        37.029041
#                                                    P5       -43.374166
#                                                    P6        10.874670
#                                                    P7        15.162151
#                                                    P8        47.552363
#                                                    P9        -3.474880
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1        13.057726
#                                                    P10       24.043601
#                                                    P11       52.286248
#                                                    P12      -15.867874
#                                                    P2        51.554052
#                                                    P3       -42.383780
#                                                    P4        55.427981
#                                                    P5       -41.360362
#                                                    P6        24.159899
#                                                    P7        25.623090
#                                                    P8        49.666306
#                                                    P9       -11.454836
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1        -7.654096
#                                                    P10       28.590385
#                                                    P11       36.689597
#                                                    P12      -25.769309
#                                                    P2        32.462991
#                                                    P3       -52.356440
#                                                    P4        40.296835
#                                                    P5       -52.167985
#                                                    P6         8.157284
#                                                    P7         8.480356
#                                                    P8        46.692287
#                                                    P9        -9.043764
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1         3.693454
#                                                    P10       28.918712
#                                                    P11       53.428009
#                                                    P12       -8.152524
#                                                    P2        40.791604
#                                                    P3       -36.924857
#                                                    P4        51.575904
#                                                    P5       -34.531098
#                                                    P6        19.373005
#                                                    P7        22.451570
#                                                    P8        57.213340
#                                                    P9        -3.823339
#
# coord                                                                 y  \
# file                                               landmark
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1       -147.044024
#                                                    P10      -130.774783
#                                                    P11       -86.358150
#                                                    P12       -98.571128
#                                                    P2       -150.381435
#                                                    P3       -149.259212
#                                                    P4       -143.026865
#                                                    P5       -147.045846
#                                                    P6       -101.817465
#                                                    P7        -89.873061
#                                                    P8       -129.287066
#                                                    P9       -133.334928
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1       -136.943983
#                                                    P10      -148.125462
#                                                    P11       -82.417774
#                                                    P12      -106.703598
#                                                    P2       -133.464523
#                                                    P3       -134.581018
#                                                    P4       -130.841246
#                                                    P5       -138.864414
#                                                    P6        -99.841765
#                                                    P7        -89.595932
#                                                    P8       -147.766833
#                                                    P9       -147.173903
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1       -148.006261
#                                                    P10      -137.225814
#                                                    P11       -79.108025
#                                                    P12       -99.540931
#                                                    P2       -145.576626
#                                                    P3       -147.674840
#                                                    P4       -140.052085
#                                                    P5       -144.625436
#                                                    P6        -93.215287
#                                                    P7        -83.523162
#                                                    P8       -137.499699
#                                                    P9       -139.199153
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1       -145.370166
#                                                    P10      -142.637157
#                                                    P11       -78.546595
#                                                    P12      -116.537444
#                                                    P2       -144.958659
#                                                    P3       -144.493124
#                                                    P4       -138.243172
#                                                    P5       -146.401211
#                                                    P6        -96.589782
#                                                    P7        -89.330830
#                                                    P8       -141.518476
#                                                    P9       -148.146547
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1       -147.104730
#                                                    P10      -138.920294
#                                                    P11       -82.928978
#                                                    P12      -118.250545
#                                                    P2       -144.676435
#                                                    P3       -147.289926
#                                                    P4       -137.333065
#                                                    P5       -145.517109
#                                                    P6       -102.314543
#                                                    P7        -91.996434
#                                                    P8       -145.596510
#                                                    P9       -150.059137
#
# coord                                                                 z
# file                                               landmark
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1        -87.783941
#                                                    P10       131.560124
#                                                    P11        56.491315
#                                                    P12        78.108477
#                                                    P2        -79.992575
#                                                    P3        -40.105323
#                                                    P4        -40.665258
#                                                    P5         -8.598625
#                                                    P6          7.775487
#                                                    P7         24.990281
#                                                    P8         85.154664
#                                                    P9        100.201894
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1        141.020477
#                                                    P10       -84.735900
#                                                    P11       -28.842337
#                                                    P12       -44.898931
#                                                    P2        126.377047
#                                                    P3         85.812440
#                                                    P4         86.480188
#                                                    P5         56.162341
#                                                    P6         25.935489
#                                                    P7          6.459927
#                                                    P8        -55.837392
#                                                    P9        -58.801446
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1        -86.720481
#                                                    P10       151.015908
#                                                    P11        73.805557
#                                                    P12        96.847264
#                                                    P2        -71.430757
#                                                    P3        -35.233825
#                                                    P4        -31.130487
#                                                    P5          0.115780
#                                                    P6         24.509018
#                                                    P7         40.598414
#                                                    P8        111.287103
#                                                    P9        121.151685
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1         99.709719
#                                                    P10      -128.910892
#                                                    P11       -77.475475
#                                                    P12       -68.911155
#                                                    P2         91.420338
#                                                    P3         50.611480
#                                                    P4         34.340595
#                                                    P5         20.733859
#                                                    P6        -12.354893
#                                                    P7        -26.859109
#                                                    P8        -95.506813
#                                                    P9       -109.074664
# /Users/knpob/Territory/Kolmo/code/foot-measure/... P1         75.718774
#                                                    P10      -150.704025
#                                                    P11      -100.221865
#                                                    P12       -95.362667
#                                                    P2         67.073977
#                                                    P3         20.002135
#                                                    P4         23.866511
#                                                    P5         -7.713319
#                                                    P6        -33.236083
#                                                    P7        -52.797964
#                                                    P8       -116.941932
#                                                    P9       -121.775075

# %%
from measure import label

file_ls = label.get_file_ls(df)
file_ls
# Out:
# Index(['/Users/knpob/Territory/Kolmo/code/foot-measure/data/22.obj',
#        '/Users/knpob/Territory/Kolmo/code/foot-measure/data/39.obj',
#        '/Users/knpob/Territory/Kolmo/code/foot-measure/data/4.obj',
#        '/Users/knpob/Territory/Kolmo/code/foot-measure/data/41.obj',
#        '/Users/knpob/Territory/Kolmo/code/foot-measure/data/46.obj'],
#       dtype='object', name='file')

# %% [markdown]
# ## Measurements

# %%
from tqdm import tqdm
import pyvista as pv
from measure import frame, metric
from mesh4d.analyse import crave

results = [
    {
        'file': 'description',
        'FL': 'foot length (mm)',
        'MBL': 'medial ball length (mm)',
        'LBL': 'lateral ball length (mm)',
        'ABW': 'anatomical ball width (mm)',
        'OBW': 'orthogonal ball width (mm)',
        'OHW': 'orthogonal heel width (mm)',
        'BH': 'ball heigh (mm)',
        'IH': 'instep height (mm)',
        'BA': 'ball angle (°)',
        'T1A': 'toe 1 angle (°)',
        'T5A': 'toe 5 angle (°)',
        'ABG': 'anatomical ball girth (mm)',
        'IG': 'instep girth (mm)',
    }
]

for file in tqdm(file_ls):
    # local frame
    mesh = crave.fix_pvmesh_disconnect(pv.read(file))
    axes_frame, origin = frame.estimate_foot_frame(mesh, file, df)
    mesh_clip = frame.foot_clip(mesh, df, file)
    mesh_local = frame.foot2local(mesh_clip, axes_frame, origin)
    df_local = frame.df2local(df, axes_frame, origin)

    # metrics
    results.append(
    {
        'file': file,
        'FL': metric.fl(df_local, file),
        'MBL': metric.mbl(df_local, file),
        'LBL': metric.lbl(df_local, file),
        'ABW': metric.abw(df_local, file),
        'OBW': metric.obw(df_local, file),
        'OHW': metric.ohw(df_local, file),
        'BH': metric.bh(df_local, file),
        'IH': metric.ih(df_local, file),
        'BA': metric.ba(df_local, file),
        'T1A': metric.t1a(df_local, file),
        'T5A': metric.t5a(df_local, file),
        'ABG': metric.abg(df_local, file, mesh_local),
        'IG': metric.ig(df_local, file, mesh_local),
    }
)

df_kirov = pd.DataFrame(results).set_index('file')
df_kirov
# Out:
# 100%|██████████| 5/5 [00:03<00:00,  1.32it/s]
#                                                                   FL  \
# file
# description                                         foot length (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        221.679943
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        229.874248
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        238.115985
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        231.892153
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        227.262808
#
#                                                                         MBL  \
# file
# description                                         medial ball length (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...               171.017628
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                169.16394
# /Users/knpob/Territory/Kolmo/code/foot-measure/...               181.492436
# /Users/knpob/Territory/Kolmo/code/foot-measure/...               159.896838
# /Users/knpob/Territory/Kolmo/code/foot-measure/...               173.058881
#
#                                                                          LBL  \
# file
# description                                         lateral ball length (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                145.312832
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                149.636607
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                152.357434
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                160.422606
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                146.178331
#
#                                                                            ABW  \
# file
# description                                         anatomical ball width (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                  101.649422
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   87.046175
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                  102.160496
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   93.850307
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   92.887961
#
#                                                                            OBW  \
# file
# description                                         orthogonal ball width (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   97.686915
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   84.693171
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   97.762887
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   90.177942
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   88.976898
#
#                                                                            OHW  \
# file
# description                                         orthogonal heel width (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   61.036592
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   50.340051
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   61.445106
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   56.922563
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   61.141694
#
#                                                                  BH  \
# file
# description                                         ball heigh (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        59.565409
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         54.59651
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        61.512783
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        74.105309
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        56.951091
#
#                                                                     IH  \
# file
# description                                         instep height (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...           69.871125
# /Users/knpob/Territory/Kolmo/code/foot-measure/...           66.482546
# /Users/knpob/Territory/Kolmo/code/foot-measure/...           70.806672
# /Users/knpob/Territory/Kolmo/code/foot-measure/...           81.613991
# /Users/knpob/Territory/Kolmo/code/foot-measure/...            67.37096
#
#                                                                 BA  \
# file
# description                                         ball angle (°)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...       71.669847
# /Users/knpob/Territory/Kolmo/code/foot-measure/...       71.000786
# /Users/knpob/Territory/Kolmo/code/foot-measure/...       69.207947
# /Users/knpob/Territory/Kolmo/code/foot-measure/...       87.754429
# /Users/knpob/Territory/Kolmo/code/foot-measure/...       70.299533
#
#                                                                 T1A  \
# file
# description                                         toe 1 angle (°)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...          28.6308
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        17.510008
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        10.299569
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         9.494463
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        17.352275
#
#                                                                 T5A  \
# file
# description                                         toe 5 angle (°)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        15.809286
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         9.540096
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        12.465447
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         18.13168
# /Users/knpob/Territory/Kolmo/code/foot-measure/...        11.748958
#
#                                                                            ABG  \
# file
# description                                         anatomical ball girth (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                  247.810337
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   209.29071
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                  513.590166
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                   453.46777
# /Users/knpob/Territory/Kolmo/code/foot-measure/...                  236.049748
#
#                                                                    IG
# file
# description                                         instep girth (mm)
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         223.287234
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         201.742682
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         237.267636
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         230.678985
# /Users/knpob/Territory/Kolmo/code/foot-measure/...         212.498477

# %% [markdown]
# ## Validation

# %%
df_manual = pd.read_pickle('../data/df-manual.pkl')

# %%
(df_manual.iloc[1:] - df_kirov.iloc[1:]).abs().mean()
# Out:
# FL      11.436411
# MBL      9.955373
# LBL      4.870703
# ABW      3.926618
# OBW      2.998908
# OHW     10.544725
# BH      12.938651
# IH      11.426172
# BA      10.843804
# T1A      5.012433
# T5A      5.470553
# ABG    118.960918
# IG      26.886636
# dtype: float64
