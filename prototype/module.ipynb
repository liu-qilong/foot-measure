# %%
import sys
sys.path.append("..")

# %%
import pandas as pd

pd.read_pickle('../output/label.pkl')
# Out:
# coord                                                                x  \
# file                                               landmark
# /Users/knpob/Territory/Kolmo/data/DynaFootLite/... P1       -47.868675
#                                                    P10       10.347754
#                                                    P11       27.356030
#                                                    P12      -40.068095
#                                                    P2        -6.773722
#                                                    P3       -76.020657
#                                                    P4         7.909824
#                                                    P5       -66.313779
#                                                    P6       -15.675663
#                                                    P7       -11.845389
#                                                    P8        33.788057
# ...
