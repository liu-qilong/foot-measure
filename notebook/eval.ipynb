# %% [markdown]
# ## Load data

# %%
import pandas as pd

udmc = pd.read_csv('output/olivia/measurements-udmc.csv', skiprows=[1]).set_index('file')
udmc
# Out:
#                                              AL         AB         AD  \
# file
# ../data/olivia/Healthy/AM004L.stl     88.494432  30.550263  60.506993
# ../data/olivia/Healthy/AF006L.obj     74.818171  34.421182  43.414930
# ../data/olivia/Healthy/BF019L.stl     89.644542  33.895219  56.272023
# ../data/olivia/Healthy/BM025L.stl    104.588646  39.023806  64.085582
# ../data/olivia/Healthy/BF036L.obj     78.521486  43.107019  42.621073
# ../data/olivia/Flat feet/AM002R.obj   80.359368  30.483895  48.071122
# ../data/olivia/Flat feet/AF008L.stl   98.667917  37.434749  57.631373
# ../data/olivia/Flat feet/BF020R.stl  101.153568  35.247210  60.629361
# ../data/olivia/Flat feet/BF021L.stl   81.283198  30.961187  51.533066
# ../data/olivia/Flat feet/BF023L.stl  106.121039  43.842147  63.481540
#
#                                             AH
# file
# ../data/olivia/Healthy/AM004L.stl    11.118538
# ../data/olivia/Healthy/AF006L.obj    18.038121
# ../data/olivia/Healthy/BF019L.stl     9.223436
# ../data/olivia/Healthy/BM025L.stl    11.665648
# ../data/olivia/Healthy/BF036L.obj    12.382572
# ../data/olivia/Flat feet/AM002R.obj  10.298465
# ../data/olivia/Flat feet/AF008L.stl  20.411065
# ../data/olivia/Flat feet/BF020R.stl  13.110396
# ../data/olivia/Flat feet/BF021L.stl  14.195625
# ../data/olivia/Flat feet/BF023L.stl  13.619875

# %%
geom = pd.read_csv('output/olivia/measurements-geomagic.csv', skiprows=[1]).set_index('file')
geom
# Out:
#                                         AL    AB    AD    AH
# file
# ../data/olivia/Healthy/AM004L.stl     70.0  38.0  46.5  10.0
# ../data/olivia/Healthy/AF006L.obj     81.5  35.0  48.5  11.5
# ../data/olivia/Healthy/BF019L.stl     88.0  40.0  48.5  15.0
# ../data/olivia/Healthy/BM025L.stl     90.0  43.0  40.0  12.0
# ../data/olivia/Healthy/BF036L.obj    100.0  51.0  43.5  15.0
# ../data/olivia/Flat feet/AM002R.obj  105.0  37.5  45.0  15.0
# ../data/olivia/Flat feet/AF008L.stl   85.0  32.5  42.5   9.0
# ../data/olivia/Flat feet/BF020R.stl  100.0  42.0  40.5  10.0
# ../data/olivia/Flat feet/BF021L.stl   81.5  41.5  33.0   3.5
# ../data/olivia/Flat feet/BF023L.stl  103.5  42.5  50.0   7.0

# %%
manual = pd.read_csv('output/olivia/measurements-manual.csv', skiprows=[1]).set_index('file')
manual
# Out:
#                                        AL  AB  AD   AH
# file
# ../data/olivia/Healthy/AM004L.stl    12.5 NaN NaN  4.7
# ../data/olivia/Healthy/AF006L.obj    12.5 NaN NaN  3.4
# ../data/olivia/Healthy/BF019L.stl    13.5 NaN NaN  4.2
# ../data/olivia/Healthy/BM025L.stl    14.2 NaN NaN  4.3
# ../data/olivia/Healthy/BF036L.obj    12.8 NaN NaN  3.8
# ../data/olivia/Flat feet/AM002R.obj  13.3 NaN NaN  2.8
# ../data/olivia/Flat feet/AF008L.stl  14.3 NaN NaN  3.2
# ../data/olivia/Flat feet/BF020R.stl  12.5 NaN NaN  3.4
# ../data/olivia/Flat feet/BF021L.stl  14.4 NaN NaN  3.6
# ../data/olivia/Flat feet/BF023L.stl  15.7 NaN NaN  3.0

# %% [markdown]
# ## Geomagic VS UdMC

# %% [markdown]
# ### Mean absolute error (MAE)

# %%
udmc - geom
# Out:
#                                             AL         AB         AD  \
# file
# ../data/olivia/Healthy/AM004L.stl    18.494432  -7.449737  14.006993
# ../data/olivia/Healthy/AF006L.obj    -6.681829  -0.578818  -5.085070
# ../data/olivia/Healthy/BF019L.stl     1.644542  -6.104781   7.772023
# ../data/olivia/Healthy/BM025L.stl    14.588646  -3.976194  24.085582
# ../data/olivia/Healthy/BF036L.obj   -21.478514  -7.892981  -0.878927
# ../data/olivia/Flat feet/AM002R.obj -24.640632  -7.016105   3.071122
# ../data/olivia/Flat feet/AF008L.stl  13.667917   4.934749  15.131373
# ../data/olivia/Flat feet/BF020R.stl   1.153568  -6.752790  20.129361
# ../data/olivia/Flat feet/BF021L.stl  -0.216802 -10.538813  18.533066
# ../data/olivia/Flat feet/BF023L.stl   2.621039   1.342147  13.481540
#
#                                             AH
# file
# ../data/olivia/Healthy/AM004L.stl     1.118538
# ../data/olivia/Healthy/AF006L.obj     6.538121
# ../data/olivia/Healthy/BF019L.stl    -5.776564
# ../data/olivia/Healthy/BM025L.stl    -0.334352
# ../data/olivia/Healthy/BF036L.obj    -2.617428
# ../data/olivia/Flat feet/AM002R.obj  -4.701535
# ../data/olivia/Flat feet/AF008L.stl  11.411065
# ../data/olivia/Flat feet/BF020R.stl   3.110396
# ../data/olivia/Flat feet/BF021L.stl  10.695625
# ../data/olivia/Flat feet/BF023L.stl   6.619875

# %%
(udmc - geom).abs().mean()
# Out:
# AL    10.518792
# AB     5.658711
# AD    12.217506
# AH     5.292350
# dtype: float64

# %% [markdown]
# ### Mean relative error (MRE)

# %%
(udmc - geom) / geom.mean()
# Out:
#                                            AL        AB        AD        AH
# file
# ../data/olivia/Healthy/AM004L.stl    0.204471 -0.184857  0.319794  0.103568
# ../data/olivia/Healthy/AF006L.obj   -0.073873 -0.014363 -0.116097  0.605382
# ../data/olivia/Healthy/BF019L.stl    0.018182 -0.151483  0.177443 -0.534867
# ../data/olivia/Healthy/BM025L.stl    0.161290 -0.098665  0.549899 -0.030959
# ../data/olivia/Healthy/BF036L.obj   -0.237463 -0.195856 -0.020067 -0.242354
# ../data/olivia/Flat feet/AM002R.obj -0.272423 -0.174097  0.070117 -0.435327
# ../data/olivia/Flat feet/AF008L.stl  0.151110  0.122450  0.345465  1.056580
# ../data/olivia/Flat feet/BF020R.stl  0.012754 -0.167563  0.459574  0.288000
# ../data/olivia/Flat feet/BF021L.stl -0.002397 -0.261509  0.423129  0.990336
# ../data/olivia/Flat feet/BF023L.stl  0.028978  0.033304  0.307798  0.612951

# %%
((udmc - geom) / geom.mean()).plot(kind='bar')
# Out:
# <Axes: xlabel='file'>

# %%
((udmc - geom) / geom.mean()).abs().mean()
# Out:
# AL    0.116294
# AB    0.140415
# AD    0.278938
# AH    0.490032
# dtype: float64

# %% [markdown]
# ## Geomagic VS Manual

# %% [markdown]
# ### Mean absolute error (MAE)

# %%
manual - geom
# Out:
#                                        AL  AB  AD    AH
# file
# ../data/olivia/Healthy/AM004L.stl   -57.5 NaN NaN  -5.3
# ../data/olivia/Healthy/AF006L.obj   -69.0 NaN NaN  -8.1
# ../data/olivia/Healthy/BF019L.stl   -74.5 NaN NaN -10.8
# ../data/olivia/Healthy/BM025L.stl   -75.8 NaN NaN  -7.7
# ../data/olivia/Healthy/BF036L.obj   -87.2 NaN NaN -11.2
# ../data/olivia/Flat feet/AM002R.obj -91.7 NaN NaN -12.2
# ../data/olivia/Flat feet/AF008L.stl -70.7 NaN NaN  -5.8
# ../data/olivia/Flat feet/BF020R.stl -87.5 NaN NaN  -6.6
# ../data/olivia/Flat feet/BF021L.stl -67.1 NaN NaN   0.1
# ../data/olivia/Flat feet/BF023L.stl -87.8 NaN NaN  -4.0

# %%
(manual - geom).abs().mean()
# Out:
# AL    76.88
# AB      NaN
# AD      NaN
# AH     7.18
# dtype: float64

# %% [markdown]
# ### Mean relative error (MRE)

# %%
(manual - geom) / geom.mean()
# Out:
#                                            AL  AB  AD        AH
# file
# ../data/olivia/Healthy/AM004L.stl   -0.635710 NaN NaN -0.490741
# ../data/olivia/Healthy/AF006L.obj   -0.762852 NaN NaN -0.750000
# ../data/olivia/Healthy/BF019L.stl   -0.823659 NaN NaN -1.000000
# ../data/olivia/Healthy/BM025L.stl   -0.838032 NaN NaN -0.712963
# ../data/olivia/Healthy/BF036L.obj   -0.964069 NaN NaN -1.037037
# ../data/olivia/Flat feet/AM002R.obj -1.013820 NaN NaN -1.129630
# ../data/olivia/Flat feet/AF008L.stl -0.781647 NaN NaN -0.537037
# ../data/olivia/Flat feet/BF020R.stl -0.967385 NaN NaN -0.611111
# ../data/olivia/Flat feet/BF021L.stl -0.741846 NaN NaN  0.009259
# ../data/olivia/Flat feet/BF023L.stl -0.970702 NaN NaN -0.370370

# %%
((manual - geom) / geom.mean()).plot(kind='bar')
# Out:
# <Axes: xlabel='file'>

# %%
((manual - geom) / geom.mean()).abs().mean()
# Out:
# AL    0.849972
# AB         NaN
# AD         NaN
# AH    0.664815
# dtype: float64
